# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 2.7 MB/s eta 0:00:00
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.1.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/joana/git/ogcapi-simple/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/joana/git/ogcapi-simple/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 35.7 MB/s eta 0:00:00m eta 0:00:010:0101
# Downloading numpy-2.1.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 37.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading pytz-2024.2-py2.py3-none-any.whl (508 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 33.9 MB/s eta 0:00:00
# Downloading tzdata-2024.2-py2.py3-none-any.whl (346 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 45.2 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.1.2 pandas-2.2.3 pytz-2024.2 tzdata-2024.2

# %%
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.35-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.6 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy)
#   Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Downloading SQLAlchemy-2.0.35-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 18.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading greenlet-3.1.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (613 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 613.1/613.1 kB 34.1 MB/s eta 0:00:00
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: typing-extensions, greenlet, sqlalchemy
# Successfully installed greenlet-3.1.1 sqlalchemy-2.0.35 typing-extensions-4.12.2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(f"postgresql://postgres@localhost:5432/geodb")

# %%
with engine.connect().execution_options(stream_results=True) as conn:
    for df in pd.read_sql("SELECT oid::regclass::text FROM   pg_class WHERE  relkind = 'm';", conn, chunksize=1000):
        print(f"Dataframe has {len(df)} rows.")
# Out:
# Dataframe has 559 rows.

# %%
df = df.reset_index()  # make sure indexes pair with number of rows

for index, row in df.iterrows():
    print(row['oid'])
# Out:
# "vmação"
# "vbaião"
# v_fornosdealgodres
# "vcovilhã"
# vserpa
# v_belmonte
# vvouzela
# vfornosdealgodres
# vabrantes
# "valpiarça"
# v_palmela
# vbelmonte
# vpalmela
# "vlourinhã"
# "vmaÇÃo"
# vviseu
# "vbaiÃo"
# vcoimbra
# vcaminha
# vviladerei
# "v_mação"
# valmeida
# vloures
# v_viseu
# "vcovilhÃ"
# vparedesdecoura
# vferreiradoalentejo
# v_caminha
# vcastroverde
# vcaldasdarainha
# voliveiradefrades
# "v_baião"
# vtavira
# v_viladerei
# vsernancelhe
# vtorredemoncorvo
# "v_covilhã"
# vmonforte
# vmirandadocorvo
# vceloricodabeira
# v_paredesdecoura
# vestarreja
# vmontalegre
# v_serpa
# v_vouzela
# vvianadoalentejo
# vviladoconde
# vcarregaldosal
# "v_alpiarça"
# "vmurça"
# velvas
# "vmortágua"
# "v_lourinhã"
# v_coimbra
# varganil
# vmealhada
# v_almeida
# "vloulé"
# vvaledecambra
# vamadora
# v_loures
# valandroal
# v_ferreiradoalentejo
# vmontijo
# v_castroverde
# "vproença-a-nova"
# vvidigueira
# "vpóvoadevarzim"
# v_oliveiradefrades
# "valcácerdosal"
# vvimioso
# vpenedono
# v_caldasdarainha
# v_tavira
# vportalegre
# "vmourão"
# vaguiardabeira
# v_sernancelhe
# vsesimbra
# "vourém"
# "vcarrazedadeansiães"
# v_torredemoncorvo
# v_monforte
# "vfreixodeespadaàcinta"
# vmondimdebasto
# v_mirandadocorvo
# vmatosinhos
# vcoruche
# vvianadocastelo
# v_celoricodabeira
# "valvaiázere"
# v_estarreja
# vmonchique
# v_montalegre
# vvilanovadepaiva
# valmeirim
# "valbergaria-a-velha"
# v_vianadoalentejo
# vriomaior
# "vsãojoãodamadeira"
# vparedes
# v_viladoconde
# v_carregaldosal
# vbarreiro
# vbatalha
# "v_murça"
# vsantamariadafeira
# "valijó"
# vespinho
# v_elvas
# "vtábua"
# "v_mortágua"
# vvilanovadepoiares
# v_arganil
# vvilanovadegaia
# vvilafrancadexira
# vodivelas
# "v_loulé"
# vvieiradominho
# ventroncamento
# v_mealhada
# v_valedecambra
# "vgavião"
# vsoure
# "vsetúbal"
# v_amadora
# vaveiro
# vsabugal
# "vpedrógãogrande"
# v_montijo
# vtrofa
# v_alandroal
# "vsantarém"
# vmora
# "v_proença-a-nova"
# "vbragança"
# vmarcodecanaveses
# "vgrândola"
# v_vidigueira
# "vgolegã"
# "v_póvoadevarzim"
# vlousada
# "v_alcácerdosal"
# "valterdochão"
# "voliveiradeazeméis"
# vtrancoso
# v_vimioso
# varraiolos
# vcuba
# v_portalegre
# v_penedono
# vcampomaior
# vmoura
# vtarouca
# "v_mourão"
# vbombarral
# "vpóvoadelanhoso"
# vestremoz
# v_aguiardabeira
# vvendasnovas
# v_sesimbra
# vportel
# "v_ourém"
# vpenalvadocastelo
# "vguimarães"
# vtomar
# "v_freixodeespadaàcinta"
# vbeja
# "vfundão"
# "v_carrazedadeansiães"
# valcoutim
# v_mondimdebasto
# vchaves
# "vpaçosdeferreira"
# vvalongo
# v_matosinhos
# vborba
# vvilanovadecerveira
# v_coruche
# v_vianadocastelo
# vmoita
# "vsobraldemonteagraço"
# vfigueiradafoz
# "v_alvaiázere"
# vpenacova
# "vílhavo"
# "vmêda"
# v_monchique
# "vcondeixa-a-nova"
# v_vilanovadepaiva
# "vsantamartadepenaguião"
# v_almeirim
# "vmontemor-o-velho"
# vcastrodaire
# vcartaxo
# v_riomaior
# valmada
# vguarda
# "v_albergaria-a-velha"
# vpenafiel
# "v_sãojoãodamadeira"
# "vóbidos"
# vsines
# "vvalença"
# v_paredes
# "vpesodarégua"
# valcochete
# v_barreiro
# v_batalha
# vseverdovouga
# "vfigueiródosvinhos"
# "vvilanovadefozcôa"
# v_santamariadafeira
# "vportimão"
# "vágueda"
# vmangualde
# "v_alijó"
# vlagoa
# v_vilanovadepoiares
# "vidanha-a-nova"
# v_espinho
# vceloricodebasto
# vamarante
# vsilves
# "v_tábua"
# "vconstãncia"
# "vportodemós"
# v_vilanovadegaia
# vmirandadodouro
# v_vilafrancadexira
# "vsantiagodocacém"
# vcadaval
# vfelgueiras
# v_odivelas
# vfafe
# "vsátão"
# v_entroncamento
# "v_gavião"
# "valmodôvar"
# "vvilavelhaderódão"
# vgouveia
# v_vieiradominho
# vvilapoucadeaguiar
# varouca
# vseia
# v_soure
# "valfândegadafé"
# "v_setúbal"
# "vévora"
# v_aveiro
# voleiros
# vlisboa
# varmamar
# v_sabugal
# vvilaflor
# vvilaverde
# "v_pedrógãogrande"
# vodemira
# v_trofa
# vreguengosdemonsaraz
# vsantotirso
# vanadia
# "v_santarém"
# vpontedesor
# vnelas
# v_mora
# "v_bragança"
# vsardoal
# "vgóis"
# varrudadosvinhos
# v_marcodecanaveses
# vlamego
# "vtabuaço"
# "vsãojoãodapesqueira"
# "v_grândola"
# vmurtosa
# "v_golegã"
# vredondo
# "v_alterdochão"
# "vvalpaços"
# vvizela
# vcantanhede
# v_lousada
# "vmértola"
# vterrasdebouro
# "v_oliveiradeazeméis"
# "vvilaviçosa"
# v_trancoso
# vtorresvedras
# "vansião"
# vmarinhagrande
# v_arraiolos
# varronches
# "valcobaça"
# v_cuba
# v_moura
# vavis
# vleiria
# vsabrosa
# v_campomaior
# vtondela
# valenquer
# voeiras
# v_tarouca
# vvinhais
# v_bombarral
# vribeiradepena
# "v_póvoadelanhoso"
# vesposende
# vcastelodevide
# "vvilarealdesantoantónio"
# v_estremoz
# vvilanovadabarquinha
# "vmonção"
# v_vendasnovas
# vpombal
# v_portel
# "vnazaré"
# vvagos
# vourique
# v_penalvadocastelo
# "vvilanovadefamalicão"
# valjustrel
# "v_guimarães"
# v_beja
# vfaro
# vcascais
# vpontedelima
# v_tomar
# vchamusca
# vpontedabarca
# voliveiradobairro
# "v_fundão"
# "vlousã"
# v_alcoutim
# vpenela
# v_chaves
# "vcastanheiradepêra"
# vcastelodepaiva
# vresende
# "v_paçosdeferreira"
# vnisa
# vgondomar
# v_valongo
# varcosdevaldevez
# v_borba
# vfigueiradecastelorodrigo
# valvito
# voliveiradohospital
# v_vilanovadecerveira
# vmacedodecavaleiros
# valbufeira
# "v_sobraldemonteagraço"
# v_moita
# vboticas
# vmafra
# vtorresnovas
# v_figueiradafoz
# vfronteira
# vlagos
# valcanena
# v_penacova
# vmira
# "v_ílhavo"
# "vmelgaço"
# "v_mêda"
# vseixal
# vmanteigas
# vamares
# "v_condeixa-a-nova"
# vovar
# "vsertã"
# "v_santamartadepenaguião"
# "vcinfães"
# "v_montemor-o-velho"
# vsousel
# vvilareal
# vsalvaterrademagos
# v_castrodaire
# "vmarvão"
# "volhão"
# v_cartaxo
# v_almada
# vviladobispo
# vpeniche
# vcastromarim
# v_guarda
# vpampilhosadaserra
# valjezur
# vpinhel
# v_penafiel
# vmirandela
# "v_óbidos"
# vmaia
# v_sines
# vazambuja
# vsintra
# vporto
# "v_pesodarégua"
# vbraga
# "vmontemor-o-novo"
# v_alcochete
# vcastelobranco
# "v_valença"
# vcrato
# vmoimentadabeira
# "vsãobrásdealportel"
# v_severdovouga
# vbenavente
# vpenamacor
# "v_figueiródosvinhos"
# "v_portimão"
# "vsãopedrodosul"
# vbarcelos
# vmogadouro
# "v_vilanovadefozcôa"
# "vferreiradozêzere"
# "vsantacombadão"
# vcabeceirasdebasto
# "v_águeda"
# "vmesãofrio"
# v_mangualde
# vbarrancos
# v_lagoa
# "v_idanha-a-nova"
# v_celoricodebasto
# v_amarante
# v_silves
# "v_constãncia"
# "v_portodemós"
# v_mirandadodouro
# "v_santiagodocacém"
# v_cadaval
# v_felgueiras
# v_fafe
# "v_almodôvar"
# "v_sátão"
# "v_vilavelhaderódão"
# v_gouveia
# v_vilapoucadeaguiar
# v_arouca
# v_seia
# "v_alfândegadafé"
# "v_évora"
# v_lisboa
# v_oleiros
# v_armamar
# v_vilaflor
# v_vilaverde
# v_reguengosdemonsaraz
# v_odemira
# v_santotirso
# v_pontedesor
# v_anadia
# v_sardoal
# v_nelas
# "v_góis"
# v_arrudadosvinhos
# v_lamego
# "v_tabuaço"
# "v_sãojoãodapesqueira"
# v_murtosa
# v_redondo
# "v_valpaços"
# v_vizela
# "v_mértola"
# v_cantanhede
# v_terrasdebouro
# "v_vilaviçosa"
# v_torresvedras
# "v_ansião"
# v_marinhagrande
# v_arronches
# "v_alcobaça"
# v_avis
# v_leiria
# v_sabrosa
# v_tondela
# v_alenquer
# v_oeiras
# v_vinhais
# v_ribeiradepena
# v_esposende
# v_castelodevide
# "v_vilarealdesantoantónio"
# v_vilanovadabarquinha
# "v_monção"
# v_abrantes
# v_pombal
# "v_nazaré"
# v_vagos
# v_ourique
# "v_vilanovadefamalicão"
# v_aljustrel
# v_faro
# v_cascais
# v_pontedelima
# v_chamusca
# v_pontedabarca
# v_oliveiradobairro
# "v_lousã"
# v_penela
# "v_castanheiradepêra"
# v_castelodepaiva
# v_resende
# v_nisa
# v_gondomar
# v_arcosdevaldevez
# v_figueiradecastelorodrigo
# v_alvito
# v_oliveiradohospital
# v_macedodecavaleiros
# v_albufeira
# v_boticas
# v_mafra
# v_fronteira
# v_torresnovas
# v_lagos
# v_alcanena
# v_mira
# "v_melgaço"
# v_seixal
# v_manteigas
# v_amares
# v_ovar
# "v_sertã"
# "v_cinfães"
# v_sousel
# v_vilareal
# v_salvaterrademagos
# "v_olhão"
# "v_marvão"
# v_peniche
# v_viladobispo
# v_castromarim
# v_pampilhosadaserra
# v_aljezur
# v_pinhel
# v_maia
# v_mirandela
# v_azambuja
# v_sintra
# v_porto
# v_braga
# "v_montemor-o-novo"
# v_castelobranco
# v_crato
# "v_sãobrásdealportel"
# v_moimentadabeira
# v_benavente
# v_penamacor
# "v_sãopedrodosul"
# v_mogadouro
# v_barcelos
# "v_ferreiradozêzere"
# "v_santacombadão"
# v_cabeceirasdebasto
# "v_mesãofrio"
# v_barrancos
